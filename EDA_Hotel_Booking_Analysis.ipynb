# %% [markdown]
# <a href="https://colab.research.google.com/github/khalilkhan1111/hotel/blob/main/EDA_Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**  - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member -**     Khalil Ullah Khan

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Hotel booking analysis is the procedure of analysing the trends, patterns, and behaviours connected with hotel reservations. As part of the study, it is customary to gather information on hotel reservations, such as the quantity of reservations, the dates of reservations, client demographics, and the channels used to make reservations. After that, the data is examined for trends, patterns, and insights that may help hotels make informed decisions about their pricing strategies, marketing plans, and customer service initiatives.
#
#
# The project involved investigating a dataset that consisted of two distinct types of hotels, namely city hotels and resort hotels, to gain a better understanding.
# In the given dataset there are 119390 rows and 32 column
# The columns have been categorized into three types, namely float64, int64, and objects.
# Hotel owners need to analyse hotel bookings since it helps them better understand their clients and make decisions that will increase their bottom line. Hotels may spot spikes in demand and change their pricing to optimise income by studying data on booking trends and patterns. Companies may customise their marketing initiatives to better target particular client categories by gaining insights about the preferences of their customers.
#
#
# Hotel operators can do booking analysis using a variety of data sources. These include of internal data sources such website analytics, customer relationship management (CRM) software, and hotel management systems. It is also possible to leverage outside data sources to enhance internal data, such as social media websites, online travel agents (OTAs), and trade publications.
#
# The identification of consumer demographics is one of the most important components of hotel booking analysis. Knowing the traits of travellers who make hotel reservations might help us better understand their requirements and preferences. For instance, a hotel operator can modify their marketing strategies to better target the young couples that make up a sizable portion of their bookings. By selling romance packages or planning couples' activities, they may also modify their amenities and services to better suit the demands of this demographic.
#
# Understanding the channels that clients use to book rooms is a crucial component of hotel booking analysis. The income and profitability of a hotel are significantly influenced by the booking channels that guests use. As an illustration, bookings made directly through a hotel's website often result in larger profit margins than those made through OTAs, which frequently charge fees. So, based on the booking channels that clients use, hotel owners may modify their pricing methods.
#
# Hotel managers can also benefit from hotel booking data by seeing trends and patterns in guest behaviour. Hotels, for instance, may see seasonal variations in demand, with more demand during the busiest travel times. Hotels can see these patterns by tracking booking data over time and modifying their pricing and marketing plans appropriately.
#
# The study of hotel bookings can also help hotels pinpoint areas where their customer interaction strategies need to be strengthened. Operators of hotels can spot areas where they might not be living up to guests' expectations by examining comments and evaluations from previous guests. They can then take action to remedy these issues by raising service standards or increasing their facilities and services.
#
#
# In conclusion, hotel operators must do hotel booking research in order to comprehend their clients more fully, enhance their marketing approaches, and boost revenue. Hotel owners may learn a great deal about the wants and preferences of their guests by gathering and examining data on booking patterns, client demographics, and booking channels. They may now alter their pricing, marketing, and customer interaction tactics to better serve their customers and increase income. In the end, hotel booking research may assist lodging establishments in remaining competitive in a sector that is undergoing fast change by staying ahead of the curve and adjusting to shifting consumer tastes and trends.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/khalilkhan1111/hotel/blob/main/EDA_Hotel_Booking_Analysis.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **1. Create a bar chart using the value counts of the 'hotel' column in df**
#
# **2. Which Agent made the most bookings**
#
# **3. What is the pecentage of cancellation?**
#
# **4. What is the Percentage of repeated guests?**
#
# **5. What is the Percentage distribution of required_car_parking_spaces**
#
# **6. What is the percentage distribution of Customer Type?**
#
# **7. What is the percentage of booking changes made by the customer?**
#
# **8. What is Percentage distribution of Deposite type?**
#
# **9. Which type of food is mostly preferred by the guests?**
#
# **10. From which country the most guests are coming?**
#
# **11. what is the ADR across each month?**
#
# **12. Which Distribution channel is mostly used for hotel bookings?**
#
# **13. Which hotel has highest percentage of booking cancellation?**
#
# **14. Correlation of columns**
#
# **15. Pair plotting of relationship between ADR and waiting list**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The hotel booking dataset is capable of providing answers to various inquiries, including the ideal time to reserve a hotel room, the optimal duration of stay for the most favorable daily rate, and the likelihood of a hotel receiving an above-average number of special requests. The dataset encompasses booking information for both city and resort hotels, containing relevant data like the booking date, length of stay, count of adults, children, and infants, as well as available parking spaces, among other variables.Through the thorough examination and analysis of this dataset, one can ascertain the critical factors that govern hotel reservations.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# Set maximum columns to be display in datafram as 36
pd.set_option("display.max_columns", 36)
plt.style.use('seaborn')

# Setting fontsizes,fontweight,label weight for lebels,titles.
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titlesize"] = 27
plt.rcParams["axes.titleweight"] = 'bold'
plt.rcParams['xtick.labelsize']=17
plt.rcParams['ytick.labelsize']=17
plt.rcParams["axes.labelsize"] = 22
plt.rcParams["legend.fontsize"] = 17
plt.rcParams["legend.title_fontsize"] = 17

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive  
drive.mount('drive')
file_path = '/content/drive/MyDrive/imp/project/Hotel.csv'
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df= pd.read_csv(file_path)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f' We have total {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
#  We have total 119390 rows and 32 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().value_counts()
# Out:
# hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  meal   country  market_segment  distribution_channel  is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  reserved_room_type  assigned_room_type  booking_changes  deposit_type  agent  company  days_in_waiting_list  customer_type  adr    required_car_parking_spaces  total_of_special_requests  reservation_status  reservation_status_date
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(12,9))
sns.countplot(x=df.duplicated())
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# There are around 30,000 missing values in a dataset consisting of 32 columns, including hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date. The total number of rows is 119390. To deal with the missing values, we have replaced them with 0 and removed any duplicate rows.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ###**hotel**: Type of hotel reserved (resort hotel or city hotel)
# ###**is_canceled**: Binary variable indicating if the booking was canceled or not (1 if canceled, 0 if not canceled)
# ###**lead_time**: Number of days between the booking date and arrival date
# ###**arrival_date_year**: Year of arrival date (2015-2017)
# ###**arrival_date_month**: Month of arrival date (January-December)
# ###**arrival_date_week_number**: Week number of arrival date
# ###**arrival_date_day_of_month**: Day of arrival date
# ###**stays_in_weekend_nights**: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# ###**stays_in_week_nights**: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# ###**adults**: Number of adults included in the booking
# ###**children**: Number of children included in the booking
# ###**babies**: Number of babies included in the booking
# ###**meal**: Type of meal booked
# ###**country**: Country of origin of the guest
# ###**market_segment**: Market segment designation (e.g. online travel agent, direct)
# ###**distribution_channel**: Booking distribution channel (e.g. travel agent, online)
# ###**is_repeated_guest**: Binary variable indicating if the guest is a repeated guest (1 if repeated guest, 0 if not)
# ###**previous_cancellations**: Number of previous bookings that were canceled by the guest prior to the current booking
# ###**previous_bookings_not_canceled**: Number of previous bookings that were not canceled by the guest prior to the current booking
# ###**reserved_room_type**: Code of room type reserved by the guest
# ###**assigned_room_type**: Code for the type of room assigned to the booking
# ###**booking_changes**: Number of changes or updates made to the booking before arrival
# ###**deposit_type**: Type of deposit made by the guest (non-refundable, refundable, no deposit)
# ###**agent**: ID of the travel agency that made the booking (if any)
# ###**company**: ID of the company or entity that made the booking (if any)
# ###**days_in_waiting_list**: Number of days the booking was in the waiting list before it was confirmed to the customer
# ###**customer_type**: Type of booking (transient, contract, group, or other)
# ###**adr**: Average daily rate (sum of transaction divided by total number of nights)
# ###**required_car_parking_spaces**: Number of car parking spaces required by the guest
# ###**total_of_special_requests**: Number of special requests made by the guest (e.g. high floor, early check-in)
# ###**reservation_status**: Current reservation status (cancelled, check-out, or no-show)
# ###**reservation_status_date**: Date at which the current reservation status was set

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
category_col=list(set(df.drop(columns=['reservation_status_date','country','arrival_date_month','is_canceled']).columns)-set(df.describe()))
for col in category_col:
  print(f'Unique values in column {col} are:, {(df[col].unique())}')
# Out:
# Unique values in column assigned_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# Unique values in column customer_type are:, ['Transient' 'Contract' 'Transient-Party' 'Group']
# Unique values in column hotel are:, ['Resort Hotel' 'City Hotel']
# Unique values in column market_segment are:, ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# Unique values in column meal are:, ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in column deposit_type are:, ['No Deposit' 'Refundable' 'Non Refund']
# Unique values in column distribution_channel are:, ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# Unique values in column reservation_status are:, ['Check-Out' 'Canceled' 'No-Show']
# Unique values in column reserved_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#dropping the duplicate rows
df= df.drop_duplicates()
df.shape
# Out:
# (87396, 32)

# %%
# Filling/replacing null values with 0.
null_columns=['agent','children','company']
for col in null_columns:
  df[col].fillna(0,inplace=True)
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Replacing null values with 0: Since there were around 30,000 missing values in the dataset, the null values have been replaced with 0.
#
# 2. Dropping duplicate rows: Any duplicate rows in the dataset have been removed to ensure that each row represents a unique observation.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# # **1. Create a bar chart using the value counts of the 'hotel' column in df**

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10,8))
df['hotel'].value_counts().plot(kind='bar', fontsize=20)

# Set the title and axis labels
plt.title('Bar Chart for Most Preferred Hotel',color = 'blue', fontsize=24)
plt.xlabel('Hotel', fontsize=20)
plt.ylabel('Count', fontsize=20)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart generated by this code provides a clear and concise way to visualize the count of different types of hotels in a dataset. It allows the viewer to quickly and easily compare the number of city hotels versus resort hotels, which can be useful in identifying patterns or trends in the data.
#
# In addition, the chart's title, axis labels, and font size make it easy to read and understand the information being presented. This can help viewers draw insights and make decisions based on the data presented in the chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows that there are two types of hotels in the dataset, city hotels and resort hotels. From the chart, we can see that there are more city hotels (52,000) than resort hotels (33,000). This information can be used to identify trends in hotel preferences, such as whether there is a greater demand for city hotels versus resort hotels. It can also help hotel owners and managers make informed decisions about which type of hotel to invest in or prioritize based on market demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the chart can certainly help create a positive business impact. For example, knowing that there is greater demand for city hotels than resort hotels can help businesses make decisions about where to invest their resources and marketing efforts. They can focus on expanding their city hotel offerings or promoting their city hotels more aggressively to attract more customers and generate more revenue.
#
# However, there are also potential negative implications to the insights gained from the chart. For example, if a business has invested heavily in resort hotels and the chart shows that there is less demand for resort hotels compared to city hotels, then they may experience negative growth as a result. This could result in financial losses and a decline in business performance.
#
# Overall, it is important to analyze and interpret data insights in a comprehensive manner, taking into account the specific context and circumstances of the business, to ensure that decisions are made with a balanced understanding of the potential positive and negative impacts.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# #**2. Which Agent made the most bookings**

# %%
# Chart - 2 visualization code
highest_bookings= df.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

 # as agent 0 was NAN value and we replaced it with 0 and indicates no bookings.so droping.
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True) 

# taking top 10 bookings made by agent
top_ten_highest_bookings=highest_bookings[:10]

top_ten_highest_bookings
# Out:
#      agent  Most_Bookings
# 9      9.0          28759
# 174  240.0          13028
# 14    14.0           3349
# 7      7.0           3300
# 183  250.0           2779
# 175  241.0           1644
# 27    28.0           1502
# 8      8.0           1383
# 1      1.0           1232
# 6      6.0           1117

# %%
#Visualizaing the graph

plt.figure(figsize=(18,8))
sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'])
plt.xlabel('Agent No')
plt.ylabel('Number of Bookings')
plt.title("Most Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart allows us to easily compare the number of bookings made by each agent using the y-axis, and also displays the agent number on the x-axis. Additionally, Seaborn's barplot function provides more aesthetic options for customization than matplotlib's bar chart, such as color palettes and error bars. Overall, this chart effectively represents the data and highlights the top performing agents in terms of bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows the top ten agents who made the most bookings. From the chart, we can see that Agent 9.0 has made the most bookings, followed by Agent 8, Agent 1, and Agent 6.
#
# One potential insight that can be gained from this chart is identifying which agents are the most successful in terms of making bookings. This information could be useful for the business to analyze and potentially incentivize or reward these agents in order to maintain their high level of performance.
#
# Another potential insight is that there is a significant difference in the number of bookings made between the top-performing agents and the rest of the agents. This could indicate that there may be a need to train or provide additional support to other agents to improve their performance and increase the overall number of bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight gained from the chart is that there are certain agents who are responsible for the majority of bookings. This information can help the hotel management to identify and focus on these top-performing agents, incentivizing them to continue bringing in bookings and building stronger relationships with them. This can lead to a positive business impact by increasing the hotel's overall revenue.
#
# However, there could be negative impacts if the hotel becomes too reliant on a few top-performing agents. If these agents decide to stop working with the hotel or if their performance drops for some reason, it could lead to a significant drop in bookings and revenue. Therefore, it is important for the hotel management to maintain a balance between relying on top-performing agents and also cultivating relationships with a wider pool of agents to mitigate any potential negative impact.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# #**3. What is the pecentage of cancellation?**

# %%
# Chart - 3 visualization code
#percentage of cancellation
df['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)
plt.title("Cancellation and non Cancellation")
# Out:
# Text(0.5, 1.0, 'Cancellation and non Cancellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is a suitable chart for showing the percentage distribution of categorical variables. In this case, it was used to show the proportion of canceled and non-canceled bookings in the dataset. The chart effectively displays the proportion of each category in relation to the whole dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart shows the percentage of cancellations vs non-cancellations in the dataset. The insights from the chart are:
#
# About 27.5% of the bookings in the dataset were canceled.
# The majority, which is around 72.5%, of the bookings were not canceled.
# This information can help the business in understanding the cancellation patterns and planning accordingly. The insights can also be used to create strategies to reduce the number of cancellations and increase the overall revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight gained from the pie chart is that around 27.5% of the bookings were canceled, which is a significant number. This insight can help the business identify the reasons for cancellation and work towards reducing them. For example, if the cancellations are due to issues with the booking process or payment system, the business can improve those areas to reduce the number of cancellations.
#
# On the other hand, if the cancellations are due to factors outside of the business's control, such as changes in travel plans or unforeseen circumstances, there may not be much that can be done to reduce them. However, the business can use this insight to adjust its operations accordingly, such as by overbooking less or implementing more flexible cancellation policies.
#
# Overall, while the high percentage of cancellations may initially seem like a negative insight, it can provide valuable information for the business to improve its operations and potentially even increase customer satisfaction.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# #**4. What is the Percentage of repeated guests?**

# %%
# Chart - 4 visualization code
df['is_repeated_guest'].value_counts().plot.pie(explode=(0.05,0.05),autopct='%1.1f%%',shadow=True,figsize=(12,8),fontsize=20)

plt.title(" Percentgae (%) of repeated guests")
# Out:
# Text(0.5, 1.0, ' Percentgae (%) of repeated guests')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is a good choice to show the distribution of categorical data, in this case, the percentage of repeated guests. The chart shows the proportion of guests who have previously booked at the hotel, which can give insight into customer loyalty and retention.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart shows the percentage of repeated guests and non-repeated guests. The insight obtained from the chart is that out of all the guests, only 3.9% were repeated guests, whereas 96.1% were new guests. This suggests that the hotel needs to focus more on attracting repeat customers by providing good service and incentives to retain them.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight gained from the chart is that only a small percentage of guests are repeated guests. This insight can help hotels focus on retaining their repeat customers by providing better customer service, loyalty programs, and other incentives to encourage repeat bookings. This can help to increase customer satisfaction, loyalty, and repeat business, leading to positive business impacts.
#
# There are no insights from this chart that could lead to negative growth.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# #**5. What is the Percentage distribution of required_car_parking_spaces**

# %%
# Chart - 5 visualization code
df['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(12,8),fontsize=15,labels=None)

labels=df['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, since the values are discrete and not too many in number, a pie chart provides a clear and intuitive way to convey the proportion of each value. The explode parameter adds some separation between the slices for a more clear visualization, and the autopct parameter shows the percentage values on each slice.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution of required car parking spaces is heavily skewed towards 0 with 91.6% of the observations falling into these two categories. The 1, isfalling towards 8.3% of the observations are split among the other categories (2, 3, 8 required parking spaces).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If the business is a hotel or hospitality company, understanding the distribution of required car parking spaces could help with planning and optimizing parking resources. For example, if the majority of guests only require 1 parking space, the business could allocate more parking resources to smaller parking lots or charge a premium for additional spaces.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# #**6. What is the percentage distribution of Customer Type?**

# %%
# Chart - 6 visualization code
df['customer_type'].value_counts().plot.pie(explode=[0.05]*4,shadow=True,autopct='%1.1f%%',figsize=(12,8),fontsize=15,labels=None)


labels=df['customer_type'].value_counts().index.tolist()
plt.title('% Distribution of Customer Type')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is a good choice for visualizing the distribution of the **customer_type** values because it allows us to easily compare the relative frequencies of each value as a percentage of the whole.
# The pie chart can help us identify which customer type is the most common, and which customer types are less frequent. This information can be useful for understanding the customer base and tailoring marketing strategies and service offerings accordingly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Transient customers make up the majority of customers (82.4%)
# Transient-party are the second most common customer type (13.4%)
# Contract customerscustomers are less frequent (3.6%)
# Groups are the least common (0.6%)
# These insights can be useful for businesses in the hospitality industry to better understand their customer base and tailor their marketing, pricing, and service offerings accordingly. For example, since transient customers are the most common, a hotel may want to focus on offering promotions for short-term stays or providing amenities and services that are popular among this customer segment. On the other hand, if groups are a significant minority, the hotel may want to focus on offering group discounts or packages to encourage more group bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the chart can help create a positive business impact for the hospitality industry. Understanding the distribution of customer types can help hotels tailor their marketing strategies, pricing, and service offerings to better target different customer segments. For example, a hotel may want to offer group discounts or special packages for transient customers to increase their bookings.
#
# There are no insights from this chart that would lead to negative growth. However, it is important to note that the insights gained from the chart are only a starting point for analyzing the customer base, and further analysis may be needed to fully understand the customer segments and their needs. Additionally, businesses should also consider external factors such as market trends and competition when making strategic decisions based on customer insights.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# #**7. What is the percentage of booking changes made by the customer?**

# %%
# Chart - 7 visualization code
booking_changes_df=df['booking_changes'].value_counts().reset_index().rename(columns={'index': "number_booking_changes",'booking_changes':'Counts'})

plt.figure(figsize=(12,8))
sns.barplot(x=booking_changes_df['number_booking_changes'],y=booking_changes_df['Counts']*100/df.shape[0])
plt.title("% of Booking change")
plt.xlabel('Number of booking changes')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the bar chart for this data because it is a simple and effective way to show the percentage of booking changes for different numbers of booking changes. The chart uses the length of the bars to represent the percentage of each count, which makes it easy to compare the frequency of booking changes for different numbers of booking changes.
#
# A bar chart is also useful when the data is discrete, as is the case with the number of booking changes. Since the number of possible values is relatively small (ranging from 0 to 4 in this case), a bar chart is a suitable way to visualize the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customers (around 80%) made no booking changes, indicating that they were satisfied with their original booking.
#
# A relatively small proportion of customers (around 10%) made one booking change, which suggests that they may have had a change of plans or made a mistake during the booking process.
#
# A smaller proportion of customers (around 5%) made two booking changes, while even fewer made three or four changes. This suggests that multiple changes are relatively uncommon, and may indicate that customers who make multiple changes are more indecisive or have more complex travel plans.
#
# Overall, the majority of customers made no or only one booking change, indicating that most customers are satisfied with their initial booking. This may provide insights into how businesses in the hospitality industry can optimize their booking policies and procedures to minimize the number of booking changes and ensure customer satisfaction.
#
# These insights can help businesses in the hospitality industry to understand the frequency and nature of booking changes made by customers and make informed decisions about their booking policies and procedures.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the bar chart can have a positive business impact for the hospitality industry. Understanding the frequency and nature of booking changes made by customers can help hotels and other businesses in the industry optimize their booking policies and procedures to improve customer satisfaction and increase revenue.
#
# For example, the insight that most customers made no booking changes suggests that the initial booking experience was satisfactory for the majority of customers. This can help businesses focus on improving the initial booking process and ensuring that it meets the needs and preferences of customers.
#
# On the other hand, the insight that a small proportion of customers made multiple booking changes may suggest that the hotel's booking policies and procedures are too restrictive, leading to customer dissatisfaction and negative word-of-mouth. If customers feel that they are unable to make changes to their bookings, they may be less likely to book with the hotel in the future, leading to negative growth.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# #**8. What is Percentage distribution of Deposite type?**

# %%
# Chart - 8 visualization code
df['deposit_type'].value_counts().plot.pie(explode=(0.5,0.5,0.05),autopct='%1.1f%%',shadow=False,figsize=(14,8),fontsize=20,labels=None)
plt.title("% Distribution of deposit type")
labels=df['deposit_type'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  In this case, the pie chart can clearly display the percentage distribution of different types of deposit for hotel bookings. Pie charts are particularly effective when the categories are relatively few in number, as is the case here, and when there is a clear hierarchy among the categories, such as the non-refundable and refundable deposits in this data. The use of explode and labels in the code also helps to highlight the differences between the categories and make the chart more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of bookings (98.7%) did not require a deposit, indicating that customers value flexibility and the ability to cancel their bookings without penalty.
#
# A small percentage of bookings (1.2%) required a non-refundable deposit, suggesting that some customers are willing to pay a premium for certain benefits, such as a lower room rate or guaranteed availability.
#
# A smaller percentage of bookings (0.1%) required a refundable deposit, indicating that some customers are willing to pay a deposit to secure their booking, but prefer to have the option to cancel and receive their deposit back.
#
# Overall, the insights gained from the chart could help hotels and other businesses in the hospitality industry to optimize their deposit policies and pricing strategies to better meet the needs and preferences of their customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the pie chart could potentially help create a positive business impact for hotels and other businesses in the hospitality industry. For example:
#
# The insight that the majority of bookings do not require a deposit could lead to a positive impact by allowing hotels to attract more customers who value flexibility and convenience.
#
# The insight that some customers are willing to pay a non-refundable deposit could lead to a positive impact by allowing hotels to offer lower room rates or other benefits to customers who are willing to commit to their bookings.
#
# However, there are also some potential negative impacts to consider. For example:
#
# If hotels require deposits for all bookings, they may risk losing customers who value flexibility and are not willing to pay a deposit.
#
# If hotels only offer non-refundable deposits, they may risk losing customers who are concerned about the uncertainty of their travel plans.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# #**9. Which type of food is mostly preferred by the guests?**

# %%
# Chart - 9 visualization code
plt.figure(figsize=(18,8))
sns.countplot(x=df['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar chart for this data because it is a simple and effective way to represent the count of bookings for each meal type. Bar charts are commonly used to compare different categories of data and are especially useful when the categories are discrete, as is the case with meal types in this dataset. The chart allows for easy comparison of the count of bookings for each meal type, and the use of color can help to make the chart more visually appealing and easy to read.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most popular meal type among bookings is the Bed and Breakfast option, with a count of approximately 7000 bookings.
# The second most popular meal type is Half Board, with a count of around 8000 bookings.
# The third most popular option is SC, with a count of approximately 9000 bookings.
# The fourth most popular option is No Meal/Undefined, with a count of approximately 1100 bookings.
# The All-Inclusive meal type is the least popular, with a count of fewer than 200 bookings.
# These insights give an indication of the preferred meal types among customers in the hotel industry. It can help hotel managers and operators understand customer preferences and make informed decisions about menu offerings and pricing strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact as they provide valuable information for the hotel industry. Understanding the preferred meal types among customers can help hotels tailor their menu offerings and pricing strategies to better meet customer needs, leading to increased customer satisfaction and loyalty. Additionally, this information can be used in marketing efforts to attract new customers by highlighting the most popular meal options.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# #**10.  From which country the most guests are coming?**

# %%
# Chart - 10 visualization code
# Counting the guests from various countries.
country_df=df['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]

# Visualizing by  plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar chart because it is an effective way to compare the number of guests from different countries. The x-axis represents the different countries and the y-axis represents the number of guests, making it easy to compare and identify the countries with the highest number of guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can identify the countries with the highest number of guests. The top 10 countries with the highest number of guests are displayed in the chart. We can see that Portugal has the highest number of guests, followed by the United Kingdom and Spain. This information can be useful for businesses in the hospitality industry, as they can use this data to make decisions regarding their marketing strategies and target audience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insight from this chart is the number of guests from different countries, which can help the business to identify which countries are contributing the most to their revenue and also help them to target those countries for marketing and promotional activities. On the other hand, if the number of guests from a particular country is very low, the business can try to identify the reasons for that and take corrective actions to attract more guests from those countries.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# #**11. what is the ADR across each month?**

# %%
# Chart - 11 visualization code
# set plot size and plot the line
bookings_by_months_df= df.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
plt.figure(figsize=(20,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

# set lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a line plot chart to display the average daily rate (ADR) across each month for each hotel type. A line plot is an effective way to show the trend of a variable over time, which is the case for this data. The chart also allows us to compare the ADR of the two hotel types across the same time period.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The line chart shows the Average Daily Rate (ADR) of the hotels across each month. The blue line represents the ADR for the City Hotel while the orange line represents the ADR for the Resort Hotel. Some insights gained from the chart are:
#
# The ADR for the City Hotel is higher than the Resort Hotel throughout the year.
# Both hotels experience a dip in ADR from November to January.
# The highest ADR for the City Hotel is in May, while the highest ADR for the Resort Hotel is in August.
# These insights can be used to optimize pricing strategies and promotions for each hotel based on the season and demand, potentially leading to increased revenue and profitability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can help create a positive business impact. The chart shows the average daily rate (ADR) across each month for both the city and resort hotels. This can help hotel managers to identify which months have higher ADR and which have lower ADR. They can use this information to adjust their pricing strategy and offer discounts during low ADR months to attract more customers.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# #**12. Which Distribution channel is mostly used for hotel bookings?**

# %%
# Chart - 12 visualization code
#Creating labels
labels=df['distribution_channel'].value_counts().index.tolist()

# creating new df of distribution channel
distribution_channel_df=df['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})

#adding percentage columns to the distribution_channel_df
distribution_channel_df['percentage']=round(distribution_channel_df['count']*100/df.shape[0],1)

#Creating list of percentage
sizes=distribution_channel_df['percentage'].values.tolist()

#plotting the pie chart
df['distribution_channel'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], shadow=False, figsize=(15,8),fontsize=10,labels=None)   

# setting legends with the percentage values
labels = [f'{l}, {s}%' for l, s in zip(labels, sizes)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.title(' Mostly Used Distribution Channel for Hotel Bookings ')
# Out:
# Text(0.5, 1.0, ' Mostly Used Distribution Channel for Hotel Bookings ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a pie chart to visualize the distribution of different booking channels because it allows for easy comparison between the different channels and also shows the percentage contribution of each channel in a clear and concise way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of the bookings were made through TA/TO, accounting for 79.1% of the total bookings.
# The second most popular channel was Direct bookings, with a percentage of 14.9%, followed by Groups with a percentage of 13.1%.
# The Corporate segment and GDS each account for a smaller proportion of the bookings, with 5.8% and 0.2% respectively.
# The chart shows that the hotel industry is heavily reliant on TA/TO for bookings, which can have implications for the business in terms of commission fees and dependence on third-party channels.
# Overall, the insights gained from the chart can help businesses make informed decisions about their distribution strategy and potentially consider diversifying their channels to reduce dependence on a single channel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insight from the chart is that travel agencies are the most commonly used distribution channel for hotel bookings, followed by direct bookings and corporate bookings. This information can be used by hotels to optimize their marketing and pricing strategies to target these channels more effectively, thereby increasing their revenue and profitability.
#
# However, if the hotels rely too heavily on one particular distribution channel, it can lead to negative growth if that channel becomes less popular or if there is increased competition within that channel. Therefore, hotels should strive to maintain a balanced mix of distribution channels to minimize their risk and maximize their growth potential.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# #**13. Which hotel has highest percentage of booking cancellation?**

# %%
# Chart - 13 visualization code
# creating new DataFrame where bookings are cancelled.
canceled_df=df[df['is_canceled']==1]

# Grouping by hotel
canceled_df=canceled_df.groupby('hotel').size().reset_index().rename(columns={0: "no_of_cancelled_bookings"})

# adding 'total booking column for calculating the percentage.
canceled_df['total_booikngs']=df.groupby('hotel').size().reset_index().rename(columns={0:"total_bookings"}).drop('hotel',axis=1)
canceled_df

#plotting the barchat
plt.figure(figsize=(10,8))
sns.barplot(x=canceled_df['hotel'],y=canceled_df['no_of_cancelled_bookings']*100/canceled_df['total_booikngs'])

#set labels
plt.xlabel('Hotel type')
plt.ylabel('Percentage(%)')
plt.title("Percentage of booking cancellation")
# Out:
# Text(0.5, 1.0, 'Percentage of booking cancellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to show the percentage of bookings that were cancelled for each type of hotel (City Hotel and Resort Hotel). It is an effective way to compare the rate of cancellations between the two hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the percentage of booking cancellation for each hotel type. The insight gained from the chart is that the resort hotel has a higher percentage of booking cancellation compared to the city hotel. This could be because resort hotel bookings are often made in advance, and plans change more frequently for vacation or leisure trips. On the other hand, city hotel bookings are more likely to be business or conference-related and may be less likely to be canceled. Overall, this insight could help the hotels to better understand their customer behavior and plan their strategies accordingly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the chart can help the business in a positive way. The chart shows the percentage of booking cancellations for each hotel type. The hotel with the higher percentage of cancellations can analyze the reasons for cancellation and take necessary steps to reduce the cancellation rate, such as offering more flexible booking policies or improving the quality of service.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %% [markdown]
# # **14. Correlation of columns**

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(18,10))
sns.heatmap(df.corr(),annot=True)
plt.title('Co-relation of the columns')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap displays a color-coded matrix where the color intensity represents the degree of correlation between two columns. Positive correlation is indicated by shades of red, while negative correlation is indicated by shades of blue.
#
# By visualizing the correlation between the columns, we can identify which features are strongly correlated with each other, which can help in identifying key factors that influence the target variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a strong negative correlation between 'is_canceled' and 'lead_time', which means that as lead time increases, the probability of cancellation decreases.
# There is a strong positive correlation between 'arrival_date_year' and 'stays_in_weekend_nights', which indicates that there is an increasing trend of guests staying in the hotel during weekends over the years.
# 'adr' and 'total_of_special_requests' have a positive correlation, which suggests that guests who pay higher rates for their rooms tend to make more special requests.
# There is a strong positive correlation between 'booking_changes' and 'days_in_waiting_list', which suggests that guests who have to wait longer for their booking confirmation tend to make more changes to their booking.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %% [markdown]
# #**15. Pair plotting of relationship between ADR and waiting list**

# %%
# Pair Plot visualization code
df.drop(df[df['adr'] > 5000].index, inplace=True)

# Select the columns to plot
cols = ['days_in_waiting_list', 'adr']

# Create pair plot
sns.pairplot(df[cols])

# Add title to plot
plt.suptitle('Relationship between adr and waiting list ', y=1.05)
# Out:
# Text(0.5, 1.05, 'Relationship between adr and waiting list ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This plot helps in understanding the relationship between the two variables and can be used to identify any trends or patterns that may be useful for further analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows the relationship between two variables, "days_in_waiting_list" and "adr" (average daily rate). From the plot, it can be observed that there is no strong linear correlation between the two variables. However, it is evident that the majority of the bookings have a waiting list of zero days and are in the price range of 0 to 500 euros per night. There are also some outliers with higher prices, but they have a smaller waiting list or no waiting list at all. This indicates that the price is not affected by the waiting list for most bookings.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Increase the number of bookings: The hotel can collaborate with travel agencies and distribution channels that are popular among customers. Also, they can offer special packages, discounts and loyalty rewards to attract more customers. Improving online presence, enhancing marketing strategies, and making the booking process more convenient can also help increase the number of bookings.
#
# Increase the average daily rate (ADR): To increase the ADR, the hotel can offer premium services such as spa, swimming pool, or room services for an additional cost. They can also adjust the room rates based on demand and supply, offer personalized packages to customers based on their preferences, and implement dynamic pricing strategies.
#
# Reduce booking cancellation rate: To reduce the booking cancellation rate, the hotel can offer flexible booking policies, such as free cancellation before a certain date or without any penalty for last-minute cancellations. Enhancing customer service quality, personalized communication with customers, and providing detailed information about the booking policies can also reduce the booking cancellation rate.
#
# Improve customer satisfaction: The hotel can improve customer satisfaction by providing exceptional customer service, personalized experiences, and creating a positive brand image. They can also consider providing additional services, such as free breakfast or shuttle services, based on customer preferences. Regular customer feedback and incorporating their suggestions can also enhance customer satisfaction.
#
# Optimize Revenue: The hotel can optimize revenue by implementing dynamic pricing strategies, identifying high-demand periods, and offering personalized packages. They can also focus on cost reduction by improving operational efficiency, energy-saving practices, and optimizing inventory management.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the various charts provide valuable insights into the trends, preferences, and behaviors of customers in the hospitality industry. The bar chart reveals that there are more city hotels than resort hotels, indicating a greater demand for city hotels. The chart also shows the top-performing agents, which can be useful for incentivizing or providing additional support to other agents to improve their performance. The pie charts reveal that a significant proportion of bookings are canceled, indicating a need for businesses to plan accordingly and reduce the number of cancellations. Additionally, the charts indicate that businesses need to focus on attracting repeat customers, and that transient customers are the most common customer type. The distribution of required car parking spaces is also heavily skewed towards zero, which can help businesses in planning for parking spaces.
#
# Moreover, the charts provide insights into customer preferences for meal types and the countries with the highest number of guests. The information can help businesses tailor their marketing, pricing, and service offerings accordingly. Finally, the charts provide valuable information on booking policies, pricing strategies, and customer satisfaction, which can help businesses optimize their booking policies and procedures to ensure customer satisfaction. Overall, the insights gained from the charts can help businesses in the hospitality industry make informed decisions about their operations, marketing, and customer service strategies.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
